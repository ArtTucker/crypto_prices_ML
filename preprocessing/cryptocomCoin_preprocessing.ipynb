# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
cro_df = pd.read_csv(Path('../resources/coin_CryptocomCoin.csv'), index_col='SNo')
cro_df
# Out:
#                 Name Symbol                 Date      High       Low  \
# SNo
# 1    Crypto.com Coin    CRO  2018-12-15 23:59:59  0.019845  0.016150
# 2    Crypto.com Coin    CRO  2018-12-16 23:59:59  0.017496  0.014127
# 3    Crypto.com Coin    CRO  2018-12-17 23:59:59  0.016723  0.011487
# 4    Crypto.com Coin    CRO  2018-12-18 23:59:59  0.017215  0.013553
# 5    Crypto.com Coin    CRO  2018-12-19 23:59:59  0.031509  0.015609
# ..               ...    ...                  ...       ...       ...
# 802  Crypto.com Coin    CRO  2021-02-23 23:59:59  0.220666  0.138515
# 803  Crypto.com Coin    CRO  2021-02-24 23:59:59  0.181438  0.148621
# 804  Crypto.com Coin    CRO  2021-02-25 23:59:59  0.177585  0.155505
# 805  Crypto.com Coin    CRO  2021-02-26 23:59:59  0.161195  0.146098
# 806  Crypto.com Coin    CRO  2021-02-27 23:59:59  0.157483  0.148072
#
#          Open     Close        Volume     Marketcap
# SNo
# 1    0.019542  0.017243  9.897096e+05  0.000000e+00
# ...

# %%
cro_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 806 entries, 1 to 806
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       806 non-null    object
#  1   Symbol     806 non-null    object
#  2   Date       806 non-null    object
#  3   High       806 non-null    float64
#  4   Low        806 non-null    float64
#  5   Open       806 non-null    float64
#  6   Close      806 non-null    float64
#  7   Volume     806 non-null    float64
#  8   Marketcap  806 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 63.0+ KB

# %%
cro_df['Date'] = pd.to_datetime(cro_df['Date']).dt.date
cro_df.dtypes
# Out:
# Name          object
# Symbol        object
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Marketcap    float64
# dtype: object

# %%
cro_df['DeFi'] = 'no'
cro_df['Network_EcoSys'] = 'cosmos'
cro_df['Consensus_Algo'] = 'none'
cro_df['Staking'] = 'no'
cro_df
# Out:
#                 Name Symbol        Date      High       Low      Open  \
# SNo
# 1    Crypto.com Coin    CRO  2018-12-15  0.019845  0.016150  0.019542
# 2    Crypto.com Coin    CRO  2018-12-16  0.017496  0.014127  0.017213
# 3    Crypto.com Coin    CRO  2018-12-17  0.016723  0.011487  0.015186
# 4    Crypto.com Coin    CRO  2018-12-18  0.017215  0.013553  0.014308
# 5    Crypto.com Coin    CRO  2018-12-19  0.031509  0.015609  0.016087
# ..               ...    ...         ...       ...       ...       ...
# 802  Crypto.com Coin    CRO  2021-02-23  0.220666  0.138515  0.217134
# 803  Crypto.com Coin    CRO  2021-02-24  0.181438  0.148621  0.157710
# 804  Crypto.com Coin    CRO  2021-02-25  0.177585  0.155505  0.160073
# 805  Crypto.com Coin    CRO  2021-02-26  0.161195  0.146098  0.156561
# 806  Crypto.com Coin    CRO  2021-02-27  0.157483  0.148072  0.155009
#
#         Close        Volume     Marketcap DeFi Network_EcoSys Consensus_Algo  \
# SNo
# ...
