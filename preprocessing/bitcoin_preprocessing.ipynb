# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
btc_df = pd.read_csv(Path('../resources/coin_Bitcoin.csv'), index_col='SNo')
btc_df
# Out:
#          Name Symbol                 Date          High           Low  \
# SNo
# 1     Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 2     Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 3     Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 4     Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 5     Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...       ...    ...                  ...           ...           ...
# 2858  Bitcoin    BTC  2021-02-23 23:59:59  54204.929756  45290.590268
# 2859  Bitcoin    BTC  2021-02-24 23:59:59  51290.136695  47213.498162
# 2860  Bitcoin    BTC  2021-02-25 23:59:59  51948.966982  47093.853019
# 2861  Bitcoin    BTC  2021-02-26 23:59:59  48370.785260  44454.842114
# 2862  Bitcoin    BTC  2021-02-27 23:59:59  48253.270101  45269.025766
#
#               Open         Close        Volume     Marketcap
# SNo
# ...

# %%
btc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2862 entries, 1 to 2862
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       2862 non-null   object
#  1   Symbol     2862 non-null   object
#  2   Date       2862 non-null   object
#  3   High       2862 non-null   float64
#  4   Low        2862 non-null   float64
#  5   Open       2862 non-null   float64
#  6   Close      2862 non-null   float64
#  7   Volume     2862 non-null   float64
#  8   Marketcap  2862 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 223.6+ KB

# %%
btc_df['Date'] = pd.to_datetime(btc_df['Date']).dt.date
btc_df.dtypes
# Out:
# Name          object
# Symbol        object
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Marketcap    float64
# dtype: object

# %%
btc_df['DeFi'] = 'no'
btc_df['Network_EcoSys'] = 'bitcoin'
btc_df['Consensus_Algo'] = 'PoW'
btc_df['Staking'] = 'none'
btc_df
# Out:
#          Name Symbol        Date          High           Low          Open  \
# SNo
# 1     Bitcoin    BTC  2013-04-29    147.488007    134.000000    134.444000
# 2     Bitcoin    BTC  2013-04-30    146.929993    134.050003    144.000000
# 3     Bitcoin    BTC  2013-05-01    139.889999    107.720001    139.000000
# 4     Bitcoin    BTC  2013-05-02    125.599998     92.281898    116.379997
# 5     Bitcoin    BTC  2013-05-03    108.127998     79.099998    106.250000
# ...       ...    ...         ...           ...           ...           ...
# 2858  Bitcoin    BTC  2021-02-23  54204.929756  45290.590268  54204.929756
# 2859  Bitcoin    BTC  2021-02-24  51290.136695  47213.498162  48835.087661
# 2860  Bitcoin    BTC  2021-02-25  51948.966982  47093.853019  49709.082425
# 2861  Bitcoin    BTC  2021-02-26  48370.785260  44454.842114  47180.464054
# 2862  Bitcoin    BTC  2021-02-27  48253.270101  45269.025766  46344.772237
#
# ...
