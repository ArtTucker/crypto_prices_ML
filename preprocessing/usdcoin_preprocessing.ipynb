# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
usdc_df = pd.read_csv(Path('../resources/coin_USDCoin.csv'), index_col='SNo')
usdc_df
# Out:
#          Name Symbol                 Date      High       Low      Open  \
# SNo
# 1    USD Coin   USDC  2018-10-09 23:59:59  1.008330  1.000030  1.004270
# 2    USD Coin   USDC  2018-10-10 23:59:59  1.019080  1.003970  1.004940
# 3    USD Coin   USDC  2018-10-11 23:59:59  1.031230  1.001730  1.009940
# 4    USD Coin   USDC  2018-10-12 23:59:59  1.018710  1.001140  1.008610
# 5    USD Coin   USDC  2018-10-13 23:59:59  1.020290  1.003550  1.014450
# ..        ...    ...                  ...       ...       ...       ...
# 869  USD Coin   USDC  2021-02-23 23:59:59  1.001702  0.999658  1.000021
# 870  USD Coin   USDC  2021-02-24 23:59:59  1.003368  0.999824  1.000019
# 871  USD Coin   USDC  2021-02-25 23:59:59  1.000710  0.999959  1.000220
# 872  USD Coin   USDC  2021-02-26 23:59:59  1.000474  0.999709  1.000153
# 873  USD Coin   USDC  2021-02-27 23:59:59  1.000204  0.999790  0.999973
#
#         Close        Volume     Marketcap
# SNo
# 1    1.006860  1.088030e+05  0.000000e+00
# ...

# %%
usdc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873 entries, 1 to 873
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       873 non-null    object
#  1   Symbol     873 non-null    object
#  2   Date       873 non-null    object
#  3   High       873 non-null    float64
#  4   Low        873 non-null    float64
#  5   Open       873 non-null    float64
#  6   Close      873 non-null    float64
#  7   Volume     873 non-null    float64
#  8   Marketcap  873 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 68.2+ KB

# %%
usdc_df['Date'] = pd.to_datetime(usdc_df['Date'])
usdc_df.dtypes
# Out:
# Name                 object
# Symbol               object
# Date         datetime64[ns]
# High                float64
# Low                 float64
# Open                float64
# Close               float64
# Volume              float64
# Marketcap           float64
# dtype: object
