# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
dot_df = pd.read_csv(Path('../resources/coin_Polkadot.csv'), index_col='SNo')
dot_df
# Out:
#          Name Symbol                 Date       High        Low       Open  \
# SNo
# 1    Polkadot    DOT  2020-08-21 23:59:59   3.090093   2.730919   2.896923
# 2    Polkadot    DOT  2020-08-22 23:59:59   4.510613   2.816762   2.878570
# 3    Polkadot    DOT  2020-08-23 23:59:59   4.487058   3.716271   4.487058
# 4    Polkadot    DOT  2020-08-24 23:59:59   4.783158   3.812670   3.987413
# 5    Polkadot    DOT  2020-08-25 23:59:59   5.760775   4.501223   4.584953
# ..        ...    ...                  ...        ...        ...        ...
# 187  Polkadot    DOT  2021-02-23 23:59:59  37.714168  26.757643  37.664930
# 188  Polkadot    DOT  2021-02-24 23:59:59  36.752569  31.975445  34.330861
# 189  Polkadot    DOT  2021-02-25 23:59:59  35.079181  31.059273  33.621172
# 190  Polkadot    DOT  2021-02-26 23:59:59  33.497752  28.104011  31.143730
# 191  Polkadot    DOT  2021-02-27 23:59:59  35.524110  31.396252  31.396252
#
#          Close        Volume     Marketcap
# SNo
# ...

# %%
dot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191 entries, 1 to 191
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       191 non-null    object
#  1   Symbol     191 non-null    object
#  2   Date       191 non-null    object
#  3   High       191 non-null    float64
#  4   Low        191 non-null    float64
#  5   Open       191 non-null    float64
#  6   Close      191 non-null    float64
#  7   Volume     191 non-null    float64
#  8   Marketcap  191 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 14.9+ KB

# %%
dot_df['Date'] = pd.to_datetime(dot_df['Date'])
dot_df.dtypes
# Out:
# Name                 object
# Symbol               object
# Date         datetime64[ns]
# High                float64
# Low                 float64
# Open                float64
# Close               float64
# Volume              float64
# Marketcap           float64
# dtype: object
