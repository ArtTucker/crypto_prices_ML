# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
usdt_df = pd.read_csv(Path('../resources/coin_Tether.csv'), index_col='SNo')
usdt_df
# Out:
#        SNo    Name Symbol                 Date      High       Low      Open  \
# 0        1  Tether   USDT  2015-02-26 23:59:59  1.212320  1.194710  1.210420
# 1        2  Tether   USDT  2015-03-02 23:59:59  0.607890  0.568314  0.571249
# 2        3  Tether   USDT  2015-03-03 23:59:59  0.606229  0.604416  0.605129
# 3        4  Tether   USDT  2015-03-06 23:59:59  1.000000  1.000000  1.000000
# 4        5  Tether   USDT  2015-03-07 23:59:59  1.000000  1.000000  1.000000
# ...    ...     ...    ...                  ...       ...       ...       ...
# 2184  2185  Tether   USDT  2021-02-23 23:59:59  1.000542  0.997413  1.000168
# 2185  2186  Tether   USDT  2021-02-24 23:59:59  1.000882  0.999538  0.999995
# 2186  2187  Tether   USDT  2021-02-25 23:59:59  1.001207  0.999795  1.000746
# 2187  2188  Tether   USDT  2021-02-26 23:59:59  1.000379  0.998726  1.000075
# 2188  2189  Tether   USDT  2021-02-27 23:59:59  1.001311  0.999374  0.999960
#
#          Close        Volume     Marketcap
# ...

# %%
usdt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2189 entries, 0 to 2188
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2189 non-null   int64
#  1   Name       2189 non-null   object
#  2   Symbol     2189 non-null   object
#  3   Date       2189 non-null   object
#  4   High       2189 non-null   float64
#  5   Low        2189 non-null   float64
#  6   Open       2189 non-null   float64
#  7   Close      2189 non-null   float64
#  8   Volume     2189 non-null   float64
#  9   Marketcap  2189 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 171.1+ KB

# %%
ltc_df['Date'] = pd.to_datetime(ltc_df['Date'])
ltc_df.dtypes
