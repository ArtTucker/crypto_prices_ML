# %% [markdown]
# Code repurposed from Kaggle [https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-cryptocurrencies]

# %% [markdown]
# ## import dependencies

# %%
import pandas as pd
import pandas_datareader as web
import numpy as np
from pathlib import Path
import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

# %%
import sys
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

sys.path.append("../../../crypto_prices_ml")

from config import CMC_API

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': CMC_API,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  data
except (ConnectionError, Timeout, TooManyRedirects) as e:
  e

# %%
data.
# Out:
# {'status': {'timestamp': '2021-06-19T23:56:15.136Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 474,
#   'credit_count': 25,
#   'notice': None,
#   'total_count': 5349},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 9098,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channels',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'arrington-xrp-capital',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures',
#     'galaxy-digital-portfolio',
#     'huobi-capital',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-xzy-screener'],
#    'max_supply': 21000000,
#    'circulating_supply': 18738862,
#    'total_supply': 18738862,
#    'platform': None,
#    'cmc_rank': 1,
#    'last_updated': '2021-06-19T23:55:02.000Z',
#    'quote': {'USD': {'price': 35668.695876869904,
#      'volume_24h': 31250558864.319237,
#      'percent_change_1h': 0.01608611,
#      'percent_change_24h': -0.12641569,
#      'percent_change_7d': 0.33484725,
#      'percent_change_30d': -11.95547473,
#      'percent_change_60d': -36.73431339,
#      'percent_change_90d': -37.99062486,
#      'market_cap': 668390769756.6342,
#      'last_updated': '2021-06-19T23:55:02.000Z'}}},
#   {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'num_market_pairs': 5879,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'smart-contracts',
#     'ethereum',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'arrington-xrp-capital',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures',
#     'hashkey-capital-portfolio',
#     'kinetic-capital',
#     'huobi-capital',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-xzy-screener'],
#    'max_supply': None,
#    'circulating_supply': 116359957.499,
#    'total_supply': 116359957.499,
#    'platform': None,
#    'cmc_rank': 2,
#    'last_updated': '2021-06-19T23:55:02.000Z',
#    'quote': {'USD': {'price': 2181.335161388077,
#      'volume_24h': 18788392997.371857,
#      'percent_change_1h': -0.19803142,
#      'percent_change_24h': -2.13074944,
#      'percent_change_7d': -8.17705506,
#      'percent_change_30d': -21.03510882,
#      'percent_change_60d': -6.25353495,
#      'percent_change_90d': 22.0116422,
#      'market_cap': 253820066670.19092,
#      'last_updated': '2021-06-19T23:55:02.000Z'}}},
#   {'id': 825,
#    'name': 'Tether',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'num_market_pairs': 12956,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'tags': ['payments',
#     'stablecoin',
#     'stablecoin-asset-backed',
#     'solana-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 62576335046.54169,
#    'total_supply': 64471767616.826355,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#    'cmc_rank': 3,
#    'last_updated': '2021-06-19T23:54:08.000Z',
#    'quote': {'USD': {'price': 1.00151044092402,
#      'volume_24h': 48303155477.74466,
#      'percent_change_1h': -0.00774655,
#      'percent_change_24h': -0.02848476,
#      'percent_change_7d': 0.03355105,
#      'percent_change_30d': -0.03025671,
#      'percent_change_60d': 0.14761266,
#      'percent_change_90d': 0.02403402,
#      'market_cap': 62670852903.87118,
#      'last_updated': '2021-06-19T23:54:08.000Z'}}},
#   {'id': 1839,
#    'name': 'Binance Coin',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'num_market_pairs': 543,
#    'date_added': '2017-07-25T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'payments',
#     'binance-smart-chain',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio'],
#    'max_supply': 170532785,
#    'circulating_supply': 153432897,
#    'total_supply': 169432897,
#    'platform': None,
#    'cmc_rank': 4,
#    'last_updated': '2021-06-19T23:55:08.000Z',
#    'quote': {'USD': {'price': 335.892498576212,
#      'volume_24h': 1142043343.3572834,
#      'percent_change_1h': -0.21934975,
#      'percent_change_24h': -0.28698803,
#      'percent_change_7d': -2.35712336,
#      'percent_change_30d': -13.84149063,
#      'percent_change_60d': -42.46999803,
#      'percent_change_90d': 26.93821355,
#      'market_cap': 51536959137.116585,
#      'last_updated': '2021-06-19T23:55:08.000Z'}}},
#   {'id': 2010,
#    'name': 'Cardano',
#    'symbol': 'ADA',
#    'slug': 'cardano',
#    'num_market_pairs': 257,
#    'date_added': '2017-10-01T00:00:00.000Z',
#    'tags': ['mineable',
#     'dpos',
#     'pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'staking',
#     'binance-chain'],
#    'max_supply': 45000000000,
#    'circulating_supply': 31946328269.464,
#    'total_supply': 32704886184.416,
#    'platform': None,
#    'cmc_rank': 5,
#    'last_updated': '2021-06-19T23:54:12.000Z',
#    'quote': {'USD': {'price': 1.39221461957759,
#      'volume_24h': 1828828284.603065,
#      'percent_change_1h': -0.30345854,
#      'percent_change_24h': -1.42801924,
#      'percent_change_7d': -5.86293849,
#      'percent_change_30d': -22.24877483,
#      'percent_change_60d': 10.40524249,
#      'percent_change_90d': 17.01354252,
#      'market_cap': 44476145258.57263,
#      'last_updated': '2021-06-19T23:54:12.000Z'}}},
#   {'id': 74,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'num_market_pairs': 362,
#    'date_added': '2013-12-15T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'memes',
#     'payments'],
#    'max_supply': None,
#    'circulating_supply': 130091121654.25931,
#    'total_supply': 130091121654.25931,
#    'platform': None,
#    'cmc_rank': 6,
#    'last_updated': '2021-06-19T23:55:03.000Z',
#    'quote': {'USD': {'price': 0.28795362627909,
#      'volume_24h': 1005319951.3062757,
#      'percent_change_1h': -0.31628803,
#      'percent_change_24h': -1.70003505,
#      'percent_change_7d': -7.78422218,
#      'percent_change_30d': -27.6615181,
#      'percent_change_60d': -12.56054386,
#      'percent_change_90d': 403.8390723,
#      'market_cap': 37460210227.05821,
#      'last_updated': '2021-06-19T23:55:03.000Z'}}},
#   {'id': 52,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'num_market_pairs': 641,
#    'date_added': '2013-08-04T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'binance-chain',
#     'arrington-xrp-capital',
#     'galaxy-digital-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio'],
#    'max_supply': 100000000000,
#    'circulating_supply': 46205772880,
#    'total_supply': 99990375595,
#    'platform': None,
#    'cmc_rank': 7,
#    'last_updated': '2021-06-19T23:55:03.000Z',
#    'quote': {'USD': {'price': 0.76385233341429,
#      'volume_24h': 2209831313.4324975,
#      'percent_change_1h': -1.02189239,
#      'percent_change_24h': -4.06220117,
#      'percent_change_7d': -8.31650007,
#      'percent_change_30d': -35.15370896,
#      'percent_change_60d': -44.55324492,
#      'percent_change_90d': 46.9752828,
#      'market_cap': 35294387431.598724,
#      'last_updated': '2021-06-19T23:55:03.000Z'}}},
#   {'id': 3408,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'slug': 'usd-coin',
#    'num_market_pairs': 892,
#    'date_added': '2018-10-08T00:00:00.000Z',
#    'tags': ['medium-of-exchange', 'stablecoin', 'stablecoin-asset-backed'],
#    'max_supply': None,
#    'circulating_supply': 24349191735.749718,
#    'total_supply': 24349191735.749718,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#    'cmc_rank': 8,
#    'last_updated': '2021-06-19T23:55:04.000Z',
#    'quote': {'USD': {'price': 1.00130342952616,
#      'volume_24h': 1594606718.285236,
#      'percent_change_1h': 0.00567369,
#      'percent_change_24h': -0.01723123,
#      'percent_change_7d': 0.01695952,
#      'percent_change_30d': 0.13120289,
#      'percent_change_60d': 0.13974818,
#      'percent_change_90d': 0.03495312,
#      'market_cap': 24380929191.196224,
#      'last_updated': '2021-06-19T23:55:04.000Z'}}},
#   {'id': 6636,
#    'name': 'Polkadot',
#    'symbol': 'DOT',
#    'slug': 'polkadot-new',
#    'num_market_pairs': 196,
#    'date_added': '2020-08-19T00:00:00.000Z',
#    'tags': ['substrate',
#     'polkadot',
#     'binance-chain',
#     'polkadot-ecosystem',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'coinfund-portfolio',
#     'fabric-ventures-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kinetic-capital',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 953484436.3056785,
#    'total_supply': 1084208592.7308664,
#    'platform': None,
#    'cmc_rank': 9,
#    'last_updated': '2021-06-19T23:55:06.000Z',
#    'quote': {'USD': {'price': 20.41587059834832,
#      'volume_24h': 999734944.1975644,
#      'percent_change_1h': -0.94276685,
#      'percent_change_24h': -4.54276864,
#      'percent_change_7d': -1.86459111,
#      'percent_change_30d': -29.3118746,
#      'percent_change_60d': -42.40857516,
#      'percent_change_90d': -44.53560539,
#      'market_cap': 19466214869.155823,
#      'last_updated': '2021-06-19T23:55:06.000Z'}}},
#   {'id': 7083,
#    'name': 'Uniswap',
#    'symbol': 'UNI',
#    'slug': 'uniswap',
#    'num_market_pairs': 249,
#    'date_added': '2020-09-17T00:00:00.000Z',
#    'tags': ['decentralized-exchange',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'defiance-capital',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'paradigm-xzy-screener'],
#    'max_supply': 1000000000,
#    'circulating_supply': 575171205.7341261,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#    'cmc_rank': 10,
#    'last_updated': '2021-06-19T23:54:10.000Z',
#    'quote': {'USD': {'price': 19.98879495736591,
#      'volume_24h': 268818919.2516884,
#      'percent_change_1h': -0.15556148,
#      'percent_change_24h': -1.81543339,
#      'percent_change_7d': -6.40231487,
#      'percent_change_30d': -23.94520722,
#      'percent_change_60d': -37.48163044,
#      'percent_change_90d': -38.92796262,
#      'market_cap': 11496979296.800371,
#      'last_updated': '2021-06-19T23:54:10.000Z'}}},
#   {'id': 1831,
#    'name': 'Bitcoin Cash',
#    'symbol': 'BCH',
#    'slug': 'bitcoin-cash',
#    'num_market_pairs': 564,
#    'date_added': '2017-07-23T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'marketplace',
#     'medium-of-exchange',
#     'store-of-value',
#     'enterprise-solutions',
#     'payments',
#     'binance-chain'],
#    'max_supply': 21000000,
#    'circulating_supply': 18768193.75,
#    'total_supply': 18768193.75,
#    'platform': None,
#    'cmc_rank': 11,
#    'last_updated': '2021-06-19T23:55:08.000Z',
#    'quote': {'USD': {'price': 556.2141145033818,
#      'volume_24h': 1287363814.449204,
#      'percent_change_1h': -0.32603131,
#      'percent_change_24h': -1.25283521,
#      'percent_change_7d': -4.21366053,
#      'percent_change_30d': -31.69251768,
#      'percent_change_60d': -41.11671517,
#      'percent_change_90d': 5.66058625,
#      'market_cap': 10439134267.484154,
#      'last_updated': '2021-06-19T23:55:08.000Z'}}},
#   {'id': 2,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'num_market_pairs': 727,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'binance-chain'],
#    'max_supply': 84000000,
#    'circulating_supply': 66752414.51538747,
#    'total_supply': 66752414.51538747,
#    'platform': None,
#    'cmc_rank': 12,
#    'last_updated': '2021-06-19T23:55:02.000Z',
#    'quote': {'USD': {'price': 153.70867029256206,
#      'volume_24h': 1719842469.9107807,
#      'percent_change_1h': -0.34807854,
#      'percent_change_24h': -1.63541389,
#      'percent_change_7d': -5.24341337,
#      'percent_change_30d': -27.30065022,
#      'percent_change_60d': -41.34693706,
#      'percent_change_90d': -21.74470124,
#      'market_cap': 10260424873.978127,
#      'last_updated': '2021-06-19T23:55:02.000Z'}}},
#   {'id': 5426,
#    'name': 'Solana',
#    'symbol': 'SOL',
#    'slug': 'solana',
#    'num_market_pairs': 64,
#    'date_added': '2020-04-10T00:00:00.000Z',
#    'tags': ['dpos',
#     'platform',
#     'solana-ecosystem',
#     'cms-holdings-portfolio',
#     'kinetic-capital',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 272637427.57725775,
#    'total_supply': 494519161.74206734,
#    'platform': None,
#    'cmc_rank': 13,
#    'last_updated': '2021-06-19T23:55:04.000Z',
#    'quote': {'USD': {'price': 35.42679981157544,
#      'volume_24h': 265017685.89307392,
#      'percent_change_1h': -0.02912443,
#      'percent_change_24h': -3.44251379,
#      'percent_change_7d': -3.13272002,
#      'percent_change_30d': -20.36082699,
#      'percent_change_60d': 11.47451466,
#      'percent_change_90d': 147.82495325,
#      'market_cap': 9658671567.92241,
#      'last_updated': '2021-06-19T23:55:04.000Z'}}},
#   {'id': 4687,
#    'name': 'Binance USD',
#    'symbol': 'BUSD',
#    'slug': 'binance-usd',
#    'num_market_pairs': 680,
#    'date_added': '2019-09-20T00:00:00.000Z',
#    'tags': ['stablecoin',
#     'stablecoin-asset-backed',
#     'binance-chain',
#     'binance-smart-chain'],
#    'max_supply': None,
#    'circulating_supply': 9451605492.34,
#    'total_supply': 9451605492.34,
#    'platform': {'id': 1839,
#     'name': 'Binance Chain',
#     'symbol': 'BNB',
#     'slug': 'binance-coin',
#     'token_address': 'BUSD-BD1'},
#    'cmc_rank': 14,
#    'last_updated': '2021-06-19T23:55:06.000Z',
#    'quote': {'USD': {'price': 1.00135757740535,
#      'volume_24h': 2948117302.486901,
#      'percent_change_1h': 0.00223665,
#      'percent_change_24h': -0.01167744,
#      'percent_change_7d': 0.02219017,
#      'percent_change_30d': 0.13792537,
#      'percent_change_60d': 0.13299144,
#      'percent_change_90d': 0.04344862,
#      'market_cap': 9464436778.400682,
#      'last_updated': '2021-06-19T23:55:06.000Z'}}},
#   {'id': 2416,
#    'name': 'THETA',
#    'symbol': 'THETA',
#    'slug': 'theta',
#    'num_market_pairs': 55,
#    'date_added': '2018-01-17T00:00:00.000Z',
#    'tags': ['media',
#     'collectibles-nfts',
#     'content-creation',
#     'video',
#     'huobi-capital'],
#    'max_supply': 1000000000,
#    'circulating_supply': 1000000000,
#    'total_supply': 1000000000,
#    'platform': None,
#    'cmc_rank': 15,
#    'last_updated': '2021-06-19T23:55:05.000Z',
#    'quote': {'USD': {'price': 8.95673716990193,
#      'volume_24h': 218073108.69358084,
#      'percent_change_1h': -0.08548834,
#      'percent_change_24h': -0.12496951,
#      'percent_change_7d': 14.44239266,
#      'percent_change_30d': 23.2482984,
#      'percent_change_60d': -23.7570027,
#      'percent_change_90d': -6.27448644,
#      'market_cap': 8956737169.90193,
#      'last_updated': '2021-06-19T23:55:05.000Z'}}},
#   {'id': 1975,
#    'name': 'Chainlink',
#    'symbol': 'LINK',
#    'slug': 'chainlink',
#    'num_market_pairs': 470,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'tags': ['platform',
#     'defi',
#     'oracles',
#     'smart-contracts',
#     'substrate',
#     'polkadot',
#     'polkadot-ecosystem',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'framework-ventures',
#     'polygon-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 434009553.9174637,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'cmc_rank': 16,
#    'last_updated': '2021-06-19T23:54:18.000Z',
#    'quote': {'USD': {'price': 20.46247553947372,
#      'volume_24h': 799343753.8462095,
#      'percent_change_1h': -0.72616718,
#      'percent_change_24h': -3.55690654,
#      'percent_change_7d': -5.69616165,
#      'percent_change_30d': -32.59573956,
#      'percent_change_60d': -47.30736641,
#      'percent_change_90d': -30.09011988,
#      'market_cap': 8880909880.934002,
#      'last_updated': '2021-06-19T23:54:18.000Z'}}},
#   {'id': 3890,
#    'name': 'Polygon',
#    'symbol': 'MATIC',
#    'slug': 'polygon',
#    'num_market_pairs': 135,
#    'date_added': '2019-04-28T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'state-channels',
#     'coinbase-ventures-portfolio',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'polygon-ecosystem'],
#    'max_supply': 10000000000,
#    'circulating_supply': 6293422325,
#    'total_supply': 10000000000,
#    'platform': None,
#    'cmc_rank': 17,
#    'last_updated': '2021-06-19T23:54:09.000Z',
#    'quote': {'USD': {'price': 1.3678655930985,
#      'volume_24h': 870701264.267593,
#      'percent_change_1h': -0.10420033,
#      'percent_change_24h': -0.61359273,
#      'percent_change_7d': 2.11119977,
#      'percent_change_30d': -24.65864526,
#      'percent_change_60d': 301.72886554,
#      'percent_change_90d': 259.38654985,
#      'market_cap': 8608555861.205465,
#      'last_updated': '2021-06-19T23:54:09.000Z'}}},
#   {'id': 3717,
#    'name': 'Wrapped Bitcoin',
#    'symbol': 'WBTC',
#    'slug': 'wrapped-bitcoin',
#    'num_market_pairs': 120,
#    'date_added': '2019-01-30T00:00:00.000Z',
#    'tags': ['medium-of-exchange', 'defi', 'wrapped-tokens'],
#    'max_supply': None,
#    'circulating_supply': 191561.72703911,
#    'total_supply': 191561.72703911,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#    'cmc_rank': 18,
#    'last_updated': '2021-06-19T23:55:07.000Z',
#    'quote': {'USD': {'price': 35647.103299745904,
#      'volume_24h': 94640742.40009142,
#      'percent_change_1h': -0.07265956,
#      'percent_change_24h': -0.26427261,
#      'percent_change_7d': -0.80583829,
#      'percent_change_30d': -12.2764589,
#      'percent_change_60d': -36.64907117,
#      'percent_change_90d': -38.05450251,
#      'market_cap': 6828620672.040882,
#      'last_updated': '2021-06-19T23:55:07.000Z'}}},
#   {'id': 512,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'num_market_pairs': 338,
#    'date_added': '2014-08-05T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'decentralized-exchange',
#     'smart-contracts',
#     'hashkey-capital-portfolio'],
#    'max_supply': 50001806812,
#    'circulating_supply': 23170089574.3146,
#    'total_supply': 50001803105.544525,
#    'platform': None,
#    'cmc_rank': 19,
#    'last_updated': '2021-06-19T23:55:06.000Z',
#    'quote': {'USD': {'price': 0.29157161669591,
#      'volume_24h': 376325596.8376851,
#      'percent_change_1h': -0.0321039,
#      'percent_change_24h': -1.88205787,
#      'percent_change_7d': -11.28908207,
#      'percent_change_30d': -40.53682262,
#      'percent_change_60d': -44.63595716,
#      'percent_change_90d': -28.02174805,
#      'market_cap': 6755740476.171957,
#      'last_updated': '2021-06-19T23:55:06.000Z'}}},
#   {'id': 8916,
#    'name': 'Internet Computer',
#    'symbol': 'ICP',
#    'slug': 'internet-computer',
#    'num_market_pairs': 33,
#    'date_added': '2021-03-23T00:00:00.000Z',
#    'tags': ['platform',
#     'distributed-computing',
#     'polychain-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 128985797.81,
#    'total_supply': 469540695.1115162,
#    'platform': None,
#    'cmc_rank': 20,
#    'last_updated': '2021-06-19T23:55:08.000Z',
#    'quote': {'USD': {'price': 49.39269758481021,
#      'volume_24h': 244247761.74368685,
#      'percent_change_1h': -0.53242744,
#      'percent_change_24h': 2.7637726,
#      'percent_change_7d': -19.35227326,
#      'percent_change_30d': -69.74441583,
#      'percent_change_60d': 0,
#      'percent_change_90d': 0,
#      'market_cap': 6370956503.964805,
#      'last_updated': '2021-06-19T23:55:08.000Z'}}},
#   {'id': 3077,
#    'name': 'VeChain',
#    'symbol': 'VET',
#    'slug': 'vechain',
#    'num_market_pairs': 124,
#    'date_added': '2017-08-22T00:00:00.000Z',
#    'tags': ['logistics',
#     'data-provenance',
#     'iot',
#     'smart-contracts',
#     'fenbushi-capital-portfolio'],
#    'max_supply': 86712634466,
#    'circulating_supply': 64315576989,
#    'total_supply': 86712634466,
#    'platform': None,
#    'cmc_rank': 21,
#    'last_updated': '2021-06-19T23:55:02.000Z',
#    'quote': {'USD': {'price': 0.09737724389652,
#      'volume_24h': 501169340.49636376,
#      'percent_change_1h': -0.04722095,
#      'percent_change_24h': -1.86761778,
#      'percent_change_7d': -8.13107936,
#      'percent_change_30d': -25.18307184,
#      'percent_change_60d': -61.25501378,
#      'percent_change_90d': 3.3777723,
#      'market_cap': 6262873626.803263,
#      'last_updated': '2021-06-19T23:55:02.000Z'}}},
#   {'id': 1321,
#    'name': 'Ethereum Classic',
#    'symbol': 'ETC',
#    'slug': 'ethereum-classic',
#    'num_market_pairs': 272,
#    'date_added': '2016-07-24T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'ethash',
#     'platform',
#     'smart-contracts',
#     'dcg-portfolio'],
#    'max_supply': 210700000,
#    'circulating_supply': 116313299,
#    'total_supply': 116313299,
#    'platform': None,
#    'cmc_rank': 22,
#    'last_updated': '2021-06-19T23:55:05.000Z',
#    'quote': {'USD': {'price': 51.26541426933176,
#      'volume_24h': 1637916498.686176,
#      'percent_change_1h': -0.20747061,
#      'percent_change_24h': -2.29719956,
#      'percent_change_7d': -7.31725878,
#      'percent_change_30d': -30.23468363,
#      'percent_change_60d': 52.81978877,
#      'percent_change_90d': 327.58357039,
#      'market_cap': 5962849458.267652,
#      'last_updated': '2021-06-19T23:55:05.000Z'}}},
#   {'id': 4943,
#    'name': 'Dai',
#    'symbol': 'DAI',
#    'slug': 'multi-collateral-dai',
#    'num_market_pairs': 392,
#    'date_added': '2019-11-22T00:00:00.000Z',
#    'tags': ['defi', 'stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 5263954955.470091,
#    'total_supply': 5263955444.309236,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#    'cmc_rank': 23,
#    'last_updated': '2021-06-19T23:54:08.000Z',
#    'quote': {'USD': {'price': 1.00169491488191,
#      'volume_24h': 252198269.2066302,
#      'percent_change_1h': 0.00094512,
#      'percent_change_24h': -0.03690466,
#      'percent_change_7d': 0.00041295,
#      'percent_change_30d': 0.08002231,
#      'percent_change_60d': 0.27601981,
#      'percent_change_90d': 0.01028435,
#      'market_cap': 5272876911.061822,
#      'last_updated': '2021-06-19T23:54:08.000Z'}}},
#   {'id': 2280,
#    'name': 'Filecoin',
#    'symbol': 'FIL',
#    'slug': 'filecoin',
#    'num_market_pairs': 120,
#    'date_added': '2017-12-13T00:00:00.000Z',
#    'tags': ['mineable',
#     'distributed-computing',
#     'filesharing',
#     'storage',
#     'polychain-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'hashkey-capital-portfolio',
#     'a16z-portfolio',
#     'winklevoss-capital',
#     'pantera-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 80392189,
#    'total_supply': 80392189,
#    'platform': None,
#    'cmc_rank': 24,
#    'last_updated': '2021-06-19T23:55:04.000Z',
#    'quote': {'USD': {'price': 65.13887254601833,
#      'volume_24h': 385633451.7192565,
#      'percent_change_1h': -0.25357063,
#      'percent_change_24h': -0.68486178,
#      'percent_change_7d': -6.61399931,
#      'percent_change_30d': -26.55519851,
#      'percent_change_60d': -57.667679,
#      'percent_change_90d': -19.69908605,
#      'market_cap': 5236656552.966417,
#      'last_updated': '2021-06-19T23:55:04.000Z'}}},
#   {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'num_market_pairs': 507,
#    'date_added': '2017-09-13T00:00:00.000Z',
#    'tags': ['media', 'payments'],
#    'max_supply': None,
#    'circulating_supply': 71659657369.49,
#    'total_supply': 100850743811.662,
#    'platform': None,
#    'cmc_rank': 25,
#    'last_updated': '2021-06-19T23:54:10.000Z',
#    'quote': {'USD': {'price': 0.06878609998533,
#      'volume_24h': 770316499.9512715,
#      'percent_change_1h': -0.41480591,
#      'percent_change_24h': -1.06359081,
#      'percent_change_7d': 0.85503491,
#      'percent_change_30d': -22.64912188,
#      'percent_change_60d': -48.18569227,
#      'percent_change_90d': 9.45230749,
#      'market_cap': 4929188356.732229,
#      'last_updated': '2021-06-19T23:54:10.000Z'}}},
#   {'id': 328,
#    'name': 'Monero',
#    'symbol': 'XMR',
#    'slug': 'monero',
#    'num_market_pairs': 165,
#    'date_added': '2014-05-21T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'medium-of-exchange',
#     'privacy',
#     'ringct',
#     'boostvc-portfolio',
#     'electric-capital-portfolio',
#     'galaxy-digital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 17935404.26076143,
#    'total_supply': 17935404.26076143,
#    'platform': None,
#    'cmc_rank': 26,
#    'last_updated': '2021-06-19T23:55:04.000Z',
#    'quote': {'USD': {'price': 271.9296633191187,
#      'volume_24h': 265035083.6019623,
#      'percent_change_1h': -1.41918673,
#      'percent_change_24h': 2.84704604,
#      'percent_change_7d': 11.76575389,
#      'percent_change_30d': -2.5855375,
#      'percent_change_60d': -32.41192465,
#      'percent_change_90d': 17.06833673,
#      'market_cap': 4877168442.121141,
#      'last_updated': '2021-06-19T23:55:04.000Z'}}},
#   {'id': 1765,
#    'name': 'EOS',
#    'symbol': 'EOS',
#    'slug': 'eos',
#    'num_market_pairs': 443,
#    'date_added': '2017-07-01T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'smart-contracts',
#     'binance-chain',
#     'fenbushi-capital-portfolio',
#     'galaxy-digital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 954395617.7823,
#    'total_supply': 1030562696.1215,
#    'platform': None,
#    'cmc_rank': 27,
#    'last_updated': '2021-06-19T23:55:07.000Z',
#    'quote': {'USD': {'price': 4.49342841133253,
#      'volume_24h': 803435803.934467,
#      'percent_change_1h': -0.3864121,
#      'percent_change_24h': -1.43363857,
#      'percent_change_7d': -7.1172564,
#      'percent_change_30d': -31.95572503,
#      'percent_change_60d': -32.78131241,
#      'percent_change_90d': 7.77321872,
#      'market_cap': 4288508384.5942483,
#      'last_updated': '2021-06-19T23:55:07.000Z'}}},
#   {'id': 6945,
#    'name': 'Amp',
#    'symbol': 'AMP',
#    'slug': 'amp',
#    'num_market_pairs': 19,
#    'date_added': '2020-09-08T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 92547638199,
#    'circulating_supply': 42227702186,
#    'total_supply': 99213408535,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xff20817765cb7f73d4bde2e66e067e58d11095c2'},
#    'cmc_rank': 28,
#    'last_updated': '2021-06-19T23:54:08.000Z',
#    'quote': {'USD': {'price': 0.08745643058085,
#      'volume_24h': 117271137.49190405,
#      'percent_change_1h': -1.13149587,
#      'percent_change_24h': 6.01469039,
#      'percent_change_7d': 47.32004971,
#      'percent_change_30d': 80.14452163,
#      'percent_change_60d': 75.06892925,
#      'percent_change_90d': 208.01316838,
#      'market_cap': 3693084104.8187165,
#      'last_updated': '2021-06-19T23:54:08.000Z'}}},
#   {'id': 7278,
#    'name': 'Aave',
#    'symbol': 'AAVE',
#    'slug': 'aave',
#    'num_market_pairs': 203,
#    'date_added': '2020-10-02T00:00:00.000Z',
#    'tags': ['defi',
#     'dao',
#     'yield-farming',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'lending-borowing',
#     'blockchain-capital-portfolio',
#     'defiance-capital',
#     'framework-ventures',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'polygon-ecosystem'],
#    'max_supply': 16000000,
#    'circulating_supply': 12799489.47839331,
#    'total_supply': 16000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x7Fc66500c84A76Ad7e9c93437bFc5Ac33E2DDaE9'},
#    'cmc_rank': 29,
#    'last_updated': '2021-06-19T23:55:03.000Z',
#    'quote': {'USD': {'price': 256.95768008910056,
#      'volume_24h': 149600609.9675479,
#      'percent_change_1h': 0.2255724,
#      'percent_change_24h': -2.64701483,
#      'percent_change_7d': -7.88815837,
#      'percent_change_30d': -44.74617097,
#      'percent_change_60d': -28.86978789,
#      'percent_change_90d': -30.5646747,
#      'market_cap': 3288927122.692797,
#      'last_updated': '2021-06-19T23:55:03.000Z'}}},
#   {'id': 1376,
#    'name': 'Neo',
#    'symbol': 'NEO',
#    'slug': 'neo',
#    'num_market_pairs': 247,
#    'date_added': '2016-09-08T00:00:00.000Z',
#    'tags': ['platform', 'enterprise-solutions', 'smart-contracts'],
#    'max_supply': 100000000,
#    'circulating_supply': 70538831,
#    'total_supply': 100000000,
#    'platform': None,
#    'cmc_rank': 30,
#    'last_updated': '2021-06-19T23:55:04.000Z',
#    'quote': {'USD': {'price': 44.75452072585879,
#      'volume_24h': 233940318.90928861,
#      'percent_change_1h': -0.34281848,
#      'percent_change_24h': -1.21184997,
#      'percent_change_7d': -3.27350655,
#      'percent_change_30d': -36.44499452,
#      'percent_change_60d': -58.53121017,
#      'percent_change_90d': 5.35070923,
#      'market_cap': 3156931573.9673505,
#      'last_updated': '2021-06-19T23:55:04.000Z'}}},
#   {'id': 3822,
#    'name': 'Theta Fuel',
#    'symbol': 'TFUEL',
#    'slug': 'theta-fuel',
#    'num_market_pairs': 15,
#    'date_added': '2019-03-28T00:00:00.000Z',
#    'tags': ['media', 'content-creation', 'payments'],
#    'max_supply': None,
#    'circulating_supply': 5301214400,
#    'total_supply': 5301214400,
#    'platform': None,
#    'cmc_rank': 31,
#    'last_updated': '2021-06-19T23:55:08.000Z',
#    'quote': {'USD': {'price': 0.59136125695152,
#      'volume_24h': 190775988.94186658,
#      'percent_change_1h': -0.95748542,
#      'percent_change_24h': 2.06756186,
#      'percent_change_7d': 39.2715601,
#      'percent_change_30d': 109.03677406,
#      'percent_change_60d': 89.18863904,
#      'percent_change_90d': 76.13596672,
#      'market_cap': 3134932810.953498,
#      'last_updated': '2021-06-19T23:55:08.000Z'}}},
#   {'id': 5994,
#    'name': 'SHIBA INU',
#    'symbol': 'SHIB',
#    'slug': 'shiba-inu',
#    'num_market_pairs': 86,
#    'date_added': '2020-08-01T00:00:00.000Z',
#    'tags': ['memes'],
#    'max_supply': None,
#    'circulating_supply': 394796000000000,
#    'total_supply': 1000000000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#    'cmc_rank': 32,
#    'last_updated': '2021-06-19T23:54:09.000Z',
#    'quote': {'USD': {'price': 7.61213785e-06,
#      'volume_24h': 799865427.1407377,
#      'percent_change_1h': -0.12196184,
#      'percent_change_24h': 5.65256072,
#      'percent_change_7d': 21.10577141,
#      'percent_change_30d': -20.67399603,
#      'percent_change_60d': 193.3704674,
#      'percent_change_90d': 13372.45744692,
#      'market_cap': 3005241574.6286,
#      'last_updated': '2021-06-19T23:54:09.000Z'}}},
#   {'id': 3602,
#    'name': 'Bitcoin SV',
#    'symbol': 'BSV',
#    'slug': 'bitcoin-sv',
#    'num_market_pairs': 195,
#    'date_added': '2018-11-09T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'medium-of-exchange',
#     'store-of-value',
#     'state-channels'],
#    'max_supply': 21000000,
#    'circulating_supply': 18764951.64423905,
#    'total_supply': 18764951.64423905,
#    'platform': None,
#    'cmc_rank': 33,
#    'last_updated': '2021-06-19T23:55:06.000Z',
#    'quote': {'USD': {'price': 155.91618088891002,
#      'volume_24h': 596059624.2177496,
#      'percent_change_1h': -0.41405346,
#      'percent_change_24h': -0.78846987,
#      'percent_change_7d': -3.85130352,
#      'percent_change_30d': -20.91246155,
#      'percent_change_60d': -48.61550688,
#      'percent_change_90d': -22.82688238,
#      'market_cap': 2925759594.934825,
#      'last_updated': '2021-06-19T23:55:06.000Z'}}},
#   {'id': 4030,
#    'name': 'Algorand',
#    'symbol': 'ALGO',
#    'slug': 'algorand',
#    'num_market_pairs': 126,
#    'date_added': '2019-06-20T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'arrington-xrp-capital',
#     'kinetic-capital',
#     'usv-portfolio',
#     'multicoin-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': 10000000000,
#    'circulating_supply': 3086421475.466129,
#    'total_supply': 5565752862.432788,
#    'platform': None,
#    'cmc_rank': 34,
#    'last_updated': '2021-06-19T23:54:11.000Z',
#    'quote': {'USD': {'price': 0.94173401297929,
#      'volume_24h': 99873363.95962471,
#      'percent_change_1h': -0.53251117,
#      'percent_change_24h': -4.30427649,
#      'percent_change_7d': -4.62034851,
#      'percent_change_30d': -14.37141092,
#      'percent_change_60d': -27.04739981,
#      'percent_change_90d': -20.4850034,
#      'market_cap': 2906588081.836179,
#      'last_updated': '2021-06-19T23:54:11.000Z'}}},
#   {'id': 7186,
#    'name': 'PancakeSwap',
#    'symbol': 'CAKE',
#    'slug': 'pancakeswap',
#    'num_market_pairs': 80,
#    'date_added': '2020-09-25T00:00:00.000Z',
#    'tags': ['decentralized-exchange',
#     'defi',
#     'yield-farming',
#     'binance-chain',
#     'amm',
#     'binance-smart-chain'],
#    'max_supply': None,
#    'circulating_supply': 183698142.97583422,
#    'total_supply': 183698142.97583422,
#    'platform': {'id': 1839,
#     'name': 'Binance Smart Chain',
#     'symbol': 'BNB',
#     'slug': 'binance-coin',
#     'token_address': '0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#    'cmc_rank': 35,
#    'last_updated': '2021-06-19T23:55:02.000Z',
#    'quote': {'USD': {'price': 15.48672248271977,
#      'volume_24h': 100774663.41189304,
#      'percent_change_1h': -0.21987975,
#      'percent_change_24h': -0.72227012,
#      'percent_change_7d': -1.49851015,
#      'percent_change_30d': -23.18756284,
#      'percent_change_60d': -43.38590521,
#      'percent_change_90d': 52.64901483,
#      'market_cap': 2844882160.8577228,
#      'last_updated': '2021-06-19T23:55:02.000Z'}}},
#   {'id': 4195,
#    'name': 'FTX Token',
#    'symbol': 'FTT',
#    'slug': 'ftx-token',
#    'num_market_pairs': 46,
#    'date_added': '2019-07-31T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'derivatives',
#     'cms-holdings-portfolio',
#     'kinetic-capital',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': 339228639,
#    'circulating_supply': 94346957.523749,
#    'total_supply': 345219293.590976,
#    'platform': {'id': 1839,
#     'name': 'Binance Chain',
#     'symbol': 'BNB',
#     'slug': 'binance-coin',
#     'token_address': 'FTT-F11'},
#    'cmc_rank': 36,
#    'last_updated': '2021-06-19T23:55:03.000Z',
#    'quote': {'USD': {'price': 29.63327104377703,
#      'volume_24h': 28533107.30481334,
#      'percent_change_1h': -0.17462925,
#      'percent_change_24h': -0.05773589,
#      'percent_change_7d': -3.63737842,
#      'percent_change_30d': -27.14103018,
#      'percent_change_60d': -43.56793275,
#      'percent_change_90d': -25.09050934,
#      'market_cap': 2795808964.456972,
#      'last_updated': '2021-06-19T23:55:03.000Z'}}},
#   {'id': 3635,
#    'name': 'Crypto.com Coin',
#    'symbol': 'CRO',
#    'slug': 'crypto-com-coin',
#    'num_market_pairs': 107,
#    'date_added': '2018-12-14T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'cosmos-ecosystem',
#     'centralized-exchange',
#     'mobile',
#     'payments'],
#    'max_supply': None,
#    'circulating_supply': 25263013692,
#    'total_supply': 30263013692,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#    'cmc_rank': 37,
#    'last_updated': '2021-06-19T23:55:06.000Z',
#    'quote': {'USD': {'price': 0.10850256693342,
#      'volume_24h': 46967330.26804848,
#      'percent_change_1h': -0.44111939,
#      'percent_change_24h': 2.53207895,
#      'percent_change_7d': -3.61331533,
#      'percent_change_30d': -14.35808638,
#      'percent_change_60d': -44.49772556,
#      'percent_change_90d': -51.21578787,
#      'market_cap': 2741101834.056136,
#      'last_updated': '2021-06-19T23:55:06.000Z'}}},
#   {'id': 1720,
#    'name': 'IOTA',
#    'symbol': 'MIOTA',
#    'slug': 'iota',
#    'num_market_pairs': 55,
#    'date_added': '2017-06-13T00:00:00.000Z',
#    'tags': ['dag', 'medium-of-exchange', 'iot', 'sharing-economy'],
#    'max_supply': 2779530283,
#    'circulating_supply': 2779530283,
#    'total_supply': 2779530283,
#    'platform': None,
#    'cmc_rank': 38,
#    'last_updated': '2021-06-19T23:55:07.000Z',
#    'quote': {'USD': {'price': 0.96987865427057,
#      'volume_24h': 42097582.51443668,
#      'percent_change_1h': -1.37230589,
#      'percent_change_24h': -3.83734909,
#      'percent_change_7d': -4.66111899,
#      'percent_change_30d': -26.38979407,
#      'percent_change_60d': -55.86023607,
#      'percent_change_90d': -32.41629151,
#      'market_cap': 2695807090.3803363,
#      'last_updated': '2021-06-19T23:55:07.000Z'}}},
#   {'id': 4023,
#    'name': 'Bitcoin BEP2',
#    'symbol': 'BTCB',
#    'slug': 'bitcoin-bep2',
#    'num_market_pairs': 34,
#    'date_added': '2019-06-18T00:00:00.000Z',
#    'tags': ['binance-chain'],
#    'max_supply': None,
#    'circulating_supply': 73120.64489955,
#    'total_supply': 80501,
#    'platform': {'id': 1839,
#     'name': 'Binance Chain',
#     'symbol': 'BNB',
#     'slug': 'binance-coin',
#     'token_address': 'BTCB-1DE'},
#    'cmc_rank': 39,
#    'last_updated': '2021-06-19T23:54:08.000Z',
#    'quote': {'USD': {'price': 35531.54573090121,
#      'volume_24h': 5822058.87494444,
#      'percent_change_1h': -0.46332632,
#      'percent_change_24h': -0.80739606,
#      'percent_change_7d': -0.14338136,
#      'percent_change_30d': -12.35543612,
#      'percent_change_60d': -37.21924921,
#      'percent_change_90d': -38.45473234,
#      'market_cap': 2598089538.1213493,
#      'last_updated': '2021-06-19T23:54:08.000Z'}}},
#   {'id': 2011,
#    'name': 'Tezos',
#    'symbol': 'XTZ',
#    'slug': 'tezos',
#    'num_market_pairs': 160,
#    'date_added': '2017-10-06T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'enterprise-solutions',
#     'collectibles-nfts',
#     'smart-contracts',
#     'polychain-capital-portfolio',
#     'boostvc-portfolio',
#     'winklevoss-capital'],
#    'max_supply': None,
#    'circulating_supply': 849808124.927142,
#    'total_supply': 879840206.247137,
#    'platform': None,
#    'cmc_rank': 40,
#    'last_updated': '2021-06-19T23:54:19.000Z',
#    'quote': {'USD': {'price': 3.04692069881695,
#      'volume_24h': 75274000.63292947,
#      'percent_change_1h': -0.18293757,
#      'percent_change_24h': -1.34683257,
#      'percent_change_7d': -3.16790393,
#      'percent_change_30d': -26.84592335,
#      'percent_change_60d': -46.40668354,
#      'percent_change_90d': -27.05552453,
#      'market_cap': 2589297965.86333,
#      'last_updated': '2021-06-19T23:54:19.000Z'}}},
#   {'id': 1518,
#    'name': 'Maker',
#    'symbol': 'MKR',
#    'slug': 'maker',
#    'num_market_pairs': 206,
#    'date_added': '2017-01-29T00:00:00.000Z',
#    'tags': ['store-of-value',
#     'defi',
#     'dao',
#     'polychain-capital-portfolio',
#     'governance',
#     'lending-borowing',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'paradigm-xzy-screener'],
#    'max_supply': 1005577,
#    'circulating_supply': 991423.40367497,
#    'total_supply': 991423.40367497,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2'},
#    'cmc_rank': 41,
#    'last_updated': '2021-06-19T23:55:06.000Z',
#    'quote': {'USD': {'price': 2600.1582844702652,
#      'volume_24h': 80295760.74363099,
#      'percent_change_1h': 0.18403669,
#      'percent_change_24h': -2.991512,
#      'percent_change_7d': -11.6013191,
#      'percent_change_30d': -33.61472515,
#      'percent_change_60d': -24.60896229,
#      'percent_change_90d': 23.51970436,
#      'market_cap': 2577857776.4831815,
#      'last_updated': '2021-06-19T23:55:06.000Z'}}},
#   {'id': 5034,
#    'name': 'Kusama',
#    'symbol': 'KSM',
#    'slug': 'kusama',
#    'num_market_pairs': 75,
#    'date_added': '2019-12-12T00:00:00.000Z',
#    'tags': ['substrate',
#     'polkadot-ecosystem',
#     'cms-holdings-portfolio',
#     'kinetic-capital',
#     '1confirmation-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 8470098.05726206,
#    'total_supply': 9651217.45126206,
#    'platform': None,
#    'cmc_rank': 42,
#    'last_updated': '2021-06-19T23:55:08.000Z',
#    'quote': {'USD': {'price': 303.2735098843001,
#      'volume_24h': 187759960.0860991,
#      'percent_change_1h': 0.3211105,
#      'percent_change_24h': -3.14652186,
#      'percent_change_7d': -23.78134958,
#      'percent_change_30d': -21.54054676,
#      'percent_change_60d': -20.86641586,
#      'percent_change_90d': -24.44402061,
#      'market_cap': 2568756366.890056,
#      'last_updated': '2021-06-19T23:55:08.000Z'}}},
#   {'id': 4256,
#    'name': 'Klaytn',
#    'symbol': 'KLAY',
#    'slug': 'klaytn',
#    'num_market_pairs': 45,
#    'date_added': '2020-03-30T00:00:00.000Z',
#    'tags': ['platform', 'enterprise-solutions'],
#    'max_supply': None,
#    'circulating_supply': 2475347483,
#    'total_supply': 10599214336,
#    'platform': None,
#    'cmc_rank': 43,
#    'last_updated': '2021-06-19T23:55:04.000Z',
#    'quote': {'USD': {'price': 1.02505313092011,
#      'volume_24h': 46381216.3822867,
#      'percent_change_1h': -0.96809284,
#      'percent_change_24h': -5.92256341,
#      'percent_change_7d': 5.04155144,
#      'percent_change_30d': -40.34561916,
#      'percent_change_60d': -59.72074042,
#      'percent_change_90d': -67.01031062,
#      'market_cap': 2537362687.564364,
#      'last_updated': '2021-06-19T23:55:04.000Z'}}},
#   {'id': 3794,
#    'name': 'Cosmos',
#    'symbol': 'ATOM',
#    'slug': 'cosmos',
#    'num_market_pairs': 165,
#    'date_added': '2019-03-14T00:00:00.000Z',
#    'tags': ['platform',
#     'cosmos-ecosystem',
#     'content-creation',
#     'interoperability',
#     'binance-chain',
#     'polychain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'hashkey-capital-portfolio',
#     '1confirmation-portfolio',
#     'paradigm-xzy-screener',
#     'exnetwork-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 210767262.762866,
#    'total_supply': 268551865.762866,
#    'platform': None,
#    'cmc_rank': 44,
#    'last_updated': '2021-06-19T23:54:08.000Z',
#    'quote': {'USD': {'price': 11.95108488621331,
#      'volume_24h': 161324938.32661524,
#      'percent_change_1h': -0.04703273,
#      'percent_change_24h': -3.58876735,
#      'percent_change_7d': 2.59969533,
#      'percent_change_30d': -27.9699247,
#      'percent_change_60d': -43.66330715,
#      'percent_change_90d': -41.82982807,
#      'market_cap': 2518897448.5138373,
#      'last_updated': '2021-06-19T23:54:08.000Z'}}},
#   {'id': 3957,
#    'name': 'UNUS SED LEO',
#    'symbol': 'LEO',
#    'slug': 'unus-sed-leo',
#    'num_market_pairs': 19,
#    'date_added': '2019-05-21T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'discount-token',
#     'payments',
#     'arrington-xrp-capital',
#     'kinetic-capital',
#     'alameda-research-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 953954130,
#    'total_supply': 985239504,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#    'cmc_rank': 45,
#    'last_updated': '2021-06-19T23:54:09.000Z',
#    'quote': {'USD': {'price': 2.58533780738474,
#      'volume_24h': 572245.16508994,
#      'percent_change_1h': 0.23457627,
#      'percent_change_24h': -2.44811677,
#      'percent_change_7d': 7.98982891,
#      'percent_change_30d': -11.90705359,
#      'percent_change_60d': 18.62409083,
#      'percent_change_90d': 21.80827048,
#      'market_cap': 2466293678.799817,
#      'last_updated': '2021-06-19T23:54:09.000Z'}}},
#   {'id': 4172,
#    'name': 'Terra',
#    'symbol': 'LUNA',
#    'slug': 'terra-luna',
#    'num_market_pairs': 61,
#    'date_added': '2019-07-26T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'store-of-value',
#     'defi',
#     'payments',
#     'stablecoin-algorithmically-stabilized',
#     'coinbase-ventures-portfolio',
#     'binance-labs-portfolio',
#     'solana-ecosystem',
#     'arrington-xrp-capital',
#     'hashkey-capital-portfolio',
#     'kinetic-capital',
#     'huobi-capital',
#     'pantera-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 416684375.95847607,
#    'total_supply': 994670127.157623,
#    'platform': None,
#    'cmc_rank': 46,
#    'last_updated': '2021-06-19T23:55:03.000Z',
#    'quote': {'USD': {'price': 5.77221859471343,
#      'volume_24h': 87635734.15617889,
#      'percent_change_1h': -0.26122242,
#      'percent_change_24h': -2.29427649,
#      'percent_change_7d': 5.16563146,
#      'percent_change_30d': -43.61076461,
#      'percent_change_60d': -57.09219837,
#      'percent_change_90d': -73.76097958,
#      'market_cap': 2405193303.034077,
#      'last_updated': '2021-06-19T23:55:03.000Z'}}},
#   {'id': 5805,
#    'name': 'Avalanche',
#    'symbol': 'AVAX',
#    'slug': 'avalanche',
#    'num_market_pairs': 59,
#    'date_added': '2020-07-13T00:00:00.000Z',
#    'tags': ['defi',
#     'polychain-capital-portfolio',
#     'avalanche-ecosystem',
#     'cms-holdings-portfolio',
#     'dragonfly-capital-portfolio'],
#    'max_supply': 720000000,
#    'circulating_supply': 172418164.00045115,
#    'total_supply': 385922102.3504511,
#    'platform': None,
#    'cmc_rank': 47,
#    'last_updated': '2021-06-19T23:55:06.000Z',
#    'quote': {'USD': {'price': 13.49384278332158,
#      'volume_24h': 37949871.24132168,
#      'percent_change_1h': -0.39212639,
#      'percent_change_24h': -0.84038553,
#      'percent_change_7d': -0.65495189,
#      'percent_change_30d': -45.94161007,
#      'percent_change_60d': -50.44950112,
#      'percent_change_90d': -58.9475292,
#      'market_cap': 2326583598.0110445,
#      'last_updated': '2021-06-19T23:55:06.000Z'}}},
#   {'id': 2502,
#    'name': 'Huobi Token',
#    'symbol': 'HT',
#    'slug': 'huobi-token',
#    'num_market_pairs': 145,
#    'date_added': '2018-02-03T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'discount-token',
#     'payments',
#     'kinetic-capital',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio'],
#    'max_supply': 500000000,
#    'circulating_supply': 170704593.25441208,
#    'total_supply': 500000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6f259637dcd74c767781e37bc6133cd6a68aa161'},
#    'cmc_rank': 48,
#    'last_updated': '2021-06-19T23:55:06.000Z',
#    'quote': {'USD': {'price': 12.24520822796778,
#      'volume_24h': 129403865.78802727,
#      'percent_change_1h': 0.13752106,
#      'percent_change_24h': -2.30112224,
#      'percent_change_7d': -6.29570674,
#      'percent_change_30d': -49.01234967,
#      'percent_change_60d': -36.23202508,
#      'percent_change_90d': -12.08699076,
#      'market_cap': 2090313289.87082,
# ...
#    'name': 'Ruff',
#    'symbol': 'RUFF',
#    'slug': 'ruff',
#    'num_market_pairs': 13,
#    'date_added': '2018-01-28T00:00:00.000Z',
#    'tags': ['platform', 'iot'],
#    'max_supply': None,
#    'circulating_supply': 980500000,
#    'total_supply': 1880000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xf278c1ca969095ffddded020290cf8b5c424ace2'},
#    'cmc_rank': 984,
#    'last_updated': '2021-06-19T23:55:06.000Z',
#    'quote': {'USD': {'price': 0.00700840770702,
#      'volume_24h': 696556.89070709,
#      'percent_change_1h': -0.37428955,
#      'percent_change_24h': 12.90184373,
#      'percent_change_7d': 6.1016751,
#      'percent_change_30d': -27.97527945,
#      'percent_change_60d': -76.23790681,
#      'percent_change_90d': -62.24195121,
#      'market_cap': 6871743.75673311,
#      'last_updated': '2021-06-19T23:55:06.000Z'}}},
#   {'id': 6997,
#    'name': 'SakeToken',
#    'symbol': 'SAKE',
#    'slug': 'sake-token',
#    'num_market_pairs': 2,
#    'date_added': '2020-09-11T00:00:00.000Z',
#    'tags': ['decentralized-exchange', 'defi', 'derivatives', 'amm'],
#    'max_supply': None,
#    'circulating_supply': 98277221.34005822,
#    'total_supply': 132699161.08369203,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x066798d9ef0833ccc719076dab77199ecbd178b0'},
#    'cmc_rank': 981,
#    'last_updated': '2021-06-19T23:54:09.000Z',
#    'quote': {'USD': {'price': 0.07107877757129,
#      'volume_24h': 130497.72294496,
#      'percent_change_1h': 1.08245808,
#      'percent_change_24h': -5.50918231,
#      'percent_change_7d': -30.93065223,
#      'percent_change_30d': -65.94817829,
#      'percent_change_60d': -80.96745562,
#      'percent_change_90d': -85.94011287,
#      'market_cap': 6985424.755954433,
#      'last_updated': '2021-06-19T23:54:09.000Z'}}},
#   {'id': 7976,
#    'name': 'Venus DOT',
#    'symbol': 'vDOT',
#    'slug': 'venus-dot',
#    'num_market_pairs': 1,
#    'date_added': '2020-12-14T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 16649243,
#    'total_supply': 16649243,
#    'platform': None,
#    'cmc_rank': 987,
#    'last_updated': '2021-06-19T23:55:08.000Z',
#    'quote': {'USD': {'price': 0.41156076758399,
#      'volume_24h': 0,
#      'percent_change_1h': -1.13319854,
#      'percent_change_24h': -4.44876725,
#      'percent_change_7d': -1.79778242,
#      'percent_change_30d': -29.14169814,
#      'percent_change_60d': -42.10717268,
#      'percent_change_90d': -44.34933526,
#      'market_cap': 6852175.228772373,
#      'last_updated': '2021-06-19T23:55:08.000Z'}}},
#   {'id': 3182,
#    'name': 'HitChain',
#    'symbol': 'HIT',
#    'slug': 'hitchain',
#    'num_market_pairs': 6,
#    'date_added': '2018-08-16T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 61440000000,
#    'total_supply': 102400000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x7995ab36bB307Afa6A683C24a25d90Dc1Ea83566'},
#    'cmc_rank': 985,
#    'last_updated': '2021-06-19T23:55:03.000Z',
#    'quote': {'USD': {'price': 0.00011130952886,
#      'volume_24h': 244240.58544685,
#      'percent_change_1h': -1.07849759,
#      'percent_change_24h': 1.12328386,
#      'percent_change_7d': -2.91120291,
#      'percent_change_30d': -18.34684465,
#      'percent_change_60d': -77.92048564,
#      'percent_change_90d': -45.95132552,
#      'market_cap': 6838857.4531584,
#      'last_updated': '2021-06-19T23:55:03.000Z'}}},
#   {'id': 4287,
#    'name': 'Jobchain',
#    'symbol': 'JOB',
#    'slug': 'jobchain',
#    'num_market_pairs': 9,
#    'date_added': '2019-12-23T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 100000000000,
#    'circulating_supply': 6963558292.847556,
#    'total_supply': 100000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdfbc9050f5b01df53512dcc39b4f2b2bbacd517a'},
#    'cmc_rank': 989,
#    'last_updated': '2021-06-19T23:55:04.000Z',
#    'quote': {'USD': {'price': 0.00098206075725,
#      'volume_24h': 221548.21947943,
#      'percent_change_1h': -0.45131571,
#      'percent_change_24h': 4.57417329,
#      'percent_change_7d': -6.62794912,
#      'percent_change_30d': -14.22280999,
#      'percent_change_60d': -40.39988128,
#      'percent_change_90d': -71.10379953,
#      'market_cap': 6838637.330228388,
#      'last_updated': '2021-06-19T23:55:04.000Z'}}},
#   {'id': 1881,
#    'name': 'DeepOnion',
#    'symbol': 'ONION',
#    'slug': 'deeponion',
#    'num_market_pairs': 6,
#    'date_added': '2017-08-12T00:00:00.000Z',
#    'tags': ['mineable', 'hybrid-pow-pos', 'marketplace', 'privacy'],
#    'max_supply': 25000000,
#    'circulating_supply': 22510671.82465541,
#    'total_supply': 22510671.82465541,
#    'platform': None,
#    'cmc_rank': 992,
#    'last_updated': '2021-06-19T23:55:08.000Z',
#    'quote': {'USD': {'price': 0.30311317911185,
#      'volume_24h': 4309.60786153,
#      'percent_change_1h': -0.0537972,
#      'percent_change_24h': -12.65728124,
#      'percent_change_7d': -22.48459951,
#      'percent_change_30d': -45.05798694,
#      'percent_change_60d': -27.45222259,
#      'percent_change_90d': 86.81820059,
#      'market_cap': 6823281.30071485,
#      'last_updated': '2021-06-19T23:55:08.000Z'}}},
#   {'id': 2885,
#    'name': 'Egretia',
#    'symbol': 'EGT',
#    'slug': 'egretia',
#    'num_market_pairs': 18,
#    'date_added': '2018-07-02T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 4218701581.8676558,
#    'total_supply': 8000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x8e1b448ec7adfc7fa35fc2e885678bd323176e34'},
#    'cmc_rank': 990,
#    'last_updated': '2021-06-19T23:55:08.000Z',
#    'quote': {'USD': {'price': 0.00161727274734,
#      'volume_24h': 7520775.31478515,
#      'percent_change_1h': -0.21115622,
#      'percent_change_24h': -13.19309305,
#      'percent_change_7d': -0.32092617,
#      'percent_change_30d': -41.11600946,
#      'percent_change_60d': -76.08028121,
#      'percent_change_90d': -70.80469448,
#      'market_cap': 6822791.097514708,
#      'last_updated': '2021-06-19T23:55:08.000Z'}}},
#   {'id': 8255,
#    'name': 'Prosper',
#    'symbol': 'PROS',
#    'slug': 'prosper',
#    'num_market_pairs': 6,
#    'date_added': '2021-01-13T00:00:00.000Z',
#    'tags': ['avalanche-ecosystem', 'polygon-ecosystem'],
#    'max_supply': 100000000,
#    'circulating_supply': 4474803.99,
#    'total_supply': 100000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x8642A849D0dcb7a15a974794668ADcfbe4794B56'},
#    'cmc_rank': 988,
#    'last_updated': '2021-06-19T23:55:03.000Z',
#    'quote': {'USD': {'price': 1.51937529599314,
#      'volume_24h': 2209003.29526888,
#      'percent_change_1h': -1.6107226,
#      'percent_change_24h': 17.01016426,
#      'percent_change_7d': 40.20970891,
#      'percent_change_30d': -24.28235719,
#      'percent_change_60d': -40.43919085,
#      'percent_change_90d': -63.07944264,
#      'market_cap': 6798906.6368175335,
#      'last_updated': '2021-06-19T23:55:03.000Z'}}},
#   {'id': 1721,
#    'name': 'Mysterium',
#    'symbol': 'MYST',
#    'slug': 'mysterium',
#    'num_market_pairs': 6,
#    'date_added': '2017-06-14T00:00:00.000Z',
#    'tags': ['platform', 'distributed-computing'],
#    'max_supply': None,
#    'circulating_supply': 20033628,
#    'total_supply': 32433365,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4Cf89ca06ad997bC732Dc876ed2A7F26a9E7f361'},
#    'cmc_rank': 993,
#    'last_updated': '2021-06-19T23:54:10.000Z',
#    'quote': {'USD': {'price': 0.33757043997078,
#      'volume_24h': 31791.26012417,
#      'percent_change_1h': -0.21142942,
#      'percent_change_24h': -3.62247189,
#      'percent_change_7d': -8.11524612,
#      'percent_change_30d': -33.26333317,
#      'percent_change_60d': -38.54104007,
#      'percent_change_90d': -12.23826797,
#      'market_cap': 6762760.6181709375,
#      'last_updated': '2021-06-19T23:54:10.000Z'}}},
#   {'id': 5309,
#    'name': 'OG Fan Token',
#    'symbol': 'OG',
#    'slug': 'og-fan-token',
#    'num_market_pairs': 3,
#    'date_added': '2020-03-12T00:00:00.000Z',
#    'tags': ['fan-token'],
#    'max_supply': None,
#    'circulating_supply': 1274535,
#    'total_supply': 5000000,
#    'platform': None,
#    'cmc_rank': 995,
#    'last_updated': '2021-06-19T23:55:04.000Z',
#    'quote': {'USD': {'price': 5.29300541027045,
#      'volume_24h': 1498078.65225979,
#      'percent_change_1h': -1.68101848,
#      'percent_change_24h': 1.41165546,
#      'percent_change_7d': -4.82535829,
#      'percent_change_30d': -37.84200418,
#      'percent_change_60d': -46.88001125,
#      'percent_change_90d': -35.8277622,
#      'market_cap': 6746120.650579047,
#      'last_updated': '2021-06-19T23:55:04.000Z'}}},
#   {'id': 7552,
#    'name': 'Hyve',
#    'symbol': 'HYVE',
#    'slug': 'hyve',
#    'num_market_pairs': 8,
#    'date_added': '2020-10-30T00:00:00.000Z',
#    'tags': ['ethereum', 'exnetwork-capital-portfolio'],
#    'max_supply': 100000000,
#    'circulating_supply': 25646075.20044982,
#    'total_supply': 99207917.48398775,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xd794DD1CAda4cf79C9EebaAb8327a1B0507ef7d4'},
#    'cmc_rank': 996,
#    'last_updated': '2021-06-19T23:55:05.000Z',
#    'quote': {'USD': {'price': 0.26257963839901,
#      'volume_24h': 1260465.79153966,
#      'percent_change_1h': -0.10548789,
#      'percent_change_24h': -5.17150093,
#      'percent_change_7d': -11.27166653,
#      'percent_change_30d': 0.90121776,
#      'percent_change_60d': 20.52524604,
#      'percent_change_90d': 33.98833857,
#      'market_cap': 6734137.152487932,
#      'last_updated': '2021-06-19T23:55:05.000Z'}}},
#   {'id': 7512,
#    'name': 'Unistake',
#    'symbol': 'UNISTAKE',
#    'slug': 'unistake',
#    'num_market_pairs': 4,
#    'date_added': '2020-10-26T00:00:00.000Z',
#    'tags': ['defi', 'ethereum'],
#    'max_supply': 279999999,
#    'circulating_supply': 175911445.13208666,
#    'total_supply': 279999999.9998125,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x9ed8e7c9604790f7ec589f99b94361d8aab64e5e'},
#    'cmc_rank': 986,
#    'last_updated': '2021-06-19T23:55:05.000Z',
#    'quote': {'USD': {'price': 0.03811052502899,
#      'volume_24h': 124276.15224463,
#      'percent_change_1h': -1.48890691,
#      'percent_change_24h': -1.79572622,
#      'percent_change_7d': -14.39561294,
#      'percent_change_30d': -24.14911632,
#      'percent_change_60d': -59.1801045,
#      'percent_change_90d': -73.05570843,
#      'market_cap': 6704077.5325921895,
#      'last_updated': '2021-06-19T23:55:05.000Z'}}},
#   {'id': 8579,
#    'name': 'Polkamarkets',
#    'symbol': 'POLK',
#    'slug': 'polkamarkets',
#    'num_market_pairs': 8,
#    'date_added': '2021-02-24T00:00:00.000Z',
#    'tags': ['defi',
#     'prediction-markets',
#     'polkadot',
#     'polkadot-ecosystem',
#     'polkastarter',
#     'polygon-ecosystem'],
#    'max_supply': 100000000,
#    'circulating_supply': 22900000,
#    'total_supply': 100000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xd478161c952357f05f0292b56012cd8457f1cfbf'},
#    'cmc_rank': 997,
#    'last_updated': '2021-06-19T23:55:06.000Z',
#    'quote': {'USD': {'price': 0.29260410483067,
#      'volume_24h': 122022.95904134,
#      'percent_change_1h': -0.00320576,
#      'percent_change_24h': 0.11946848,
#      'percent_change_7d': -19.87957829,
#      'percent_change_30d': -55.58425403,
#      'percent_change_60d': -80.78001982,
#      'percent_change_90d': -90.69312234,
#      'market_cap': 6700634.000622343,
#      'last_updated': '2021-06-19T23:55:06.000Z'}}},
#   {'id': 3948,
#    'name': 'TERA',
#    'symbol': 'TERA',
#    'slug': 'tera',
#    'num_market_pairs': 7,
#    'date_added': '2019-05-21T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 844711128,
#    'total_supply': 1000000000,
#    'platform': None,
#    'cmc_rank': 994,
#    'last_updated': '2021-06-19T23:54:17.000Z',
#    'quote': {'USD': {'price': 0.00795397287009,
#      'volume_24h': 147807.10631275,
#      'percent_change_1h': 1.47242197,
#      'percent_change_24h': -8.92011119,
#      'percent_change_7d': -18.26635021,
#      'percent_change_30d': -23.32256571,
#      'percent_change_60d': -58.92857126,
#      'percent_change_90d': -31.95322047,
#      'market_cap': 6718809.395175122,
#      'last_updated': '2021-06-19T23:54:17.000Z'}}},
#   {'id': 3071,
#    'name': 'EUNO',
#    'symbol': 'EUNO',
#    'slug': 'euno',
#    'num_market_pairs': 4,
#    'date_added': '2018-08-03T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 8000000000,
#    'circulating_supply': 6234560734.042055,
#    'total_supply': 6234560734.042055,
#    'platform': None,
#    'cmc_rank': 998,
#    'last_updated': '2021-06-19T23:54:12.000Z',
#    'quote': {'USD': {'price': 0.00106889912297,
#      'volume_24h': 1497.47980241,
#      'percent_change_1h': -0.18991674,
#      'percent_change_24h': -19.96408169,
#      'percent_change_7d': -24.89900376,
#      'percent_change_30d': -29.68366105,
#      'percent_change_60d': -54.53979857,
#      'percent_change_90d': -67.17957642,
#      'market_cap': 6664116.5007207515,
#      'last_updated': '2021-06-19T23:54:12.000Z'}}},
#   {'id': 2337,
#    'name': 'Lamden',
#    'symbol': 'TAU',
#    'slug': 'lamden',
#    'num_market_pairs': 1,
#    'date_added': '2018-01-04T00:00:00.000Z',
#    'tags': ['platform', 'atomic-swaps', 'interoperability', 'smart-contracts'],
#    'max_supply': None,
#    'circulating_supply': 142215728.19,
#    'total_supply': 288090567.494,
#    'platform': None,
#    'cmc_rank': 999,
#    'last_updated': '2021-06-19T23:55:04.000Z',
#    'quote': {'USD': {'price': 0.04687689261823,
#      'volume_24h': 54752.25642976,
#      'percent_change_1h': -0.19803142,
#      'percent_change_24h': -1.67320269,
#      'percent_change_7d': 2.40140565,
#      'percent_change_30d': -19.08321808,
#      'percent_change_60d': -56.56762957,
#      'percent_change_90d': -9.13838078,
#      'market_cap': 6666631.418986015,
#      'last_updated': '2021-06-19T23:55:04.000Z'}}},
#   {'id': 5590,
#    'name': 'GeoDB',
#    'symbol': 'GEO',
#    'slug': 'geodb',
#    'num_market_pairs': 4,
#    'date_added': '2020-05-15T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 350000000,
#    'circulating_supply': 27063597.51224432,
#    'total_supply': 350000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x147faf8de9d8d8daae129b187f0d02d819126750'},
#    'cmc_rank': 1002,
#    'last_updated': '2021-06-19T23:55:07.000Z',
#    'quote': {'USD': {'price': 0.24417735568078,
#      'volume_24h': 94021.83437536,
#      'percent_change_1h': -1.22301837,
#      'percent_change_24h': -2.67450746,
#      'percent_change_7d': -14.90197228,
#      'percent_change_30d': -35.28274779,
#      'percent_change_60d': -75.276621,
#      'percent_change_90d': -80.49458418,
#      'market_cap': 6608317.675748754,
#      'last_updated': '2021-06-19T23:55:07.000Z'}}},
#   {'id': 6701,
#    'name': 'Burency',
#    'symbol': 'BUY',
#    'slug': 'burency',
#    'num_market_pairs': 4,
#    'date_added': '2020-08-30T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 700000000,
#    'circulating_supply': 193878224.01706946,
#    'total_supply': 700000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x31fdd1c6607f47c14a2821f599211c67ac20fa96'},
#    'cmc_rank': 1000,
#    'last_updated': '2021-06-19T23:55:08.000Z',
#    'quote': {'USD': {'price': 0.0340799263701,
#      'volume_24h': 424662.60488411,
#      'percent_change_1h': -1.74151448,
#      'percent_change_24h': 4.64694134,
#      'percent_change_7d': 11.97793476,
#      'percent_change_30d': -62.59344952,
#      'percent_change_60d': -45.36169399,
#      'percent_change_90d': -83.25716694,
#      'market_cap': 6607355.599267481,
#      'last_updated': '2021-06-19T23:55:08.000Z'}}},
#   ...]}

# %% [markdown]
# ## load and inspect data

# %%
crypto_currency = 'ETH'
against_currency = 'USD'

start = dt.datetime(2014,1,1)
end = dt.datetime.now()

base_df = web.DataReader(f'{crypto_currency}-{against_currency}', 'yahoo', start, end)
base_df
# Out:
#                    High          Low         Open        Close        Volume  \
# Date
# 2015-08-06     3.536610     2.521120     2.831620     2.772120  1.643290e+05
# 2015-08-07     2.798810     0.714725     2.793760     0.753325  6.741880e+05
# 2015-08-08     0.879810     0.629191     0.706136     0.701897  5.321700e+05
# 2015-08-09     0.729854     0.636546     0.713989     0.708448  4.052830e+05
# 2015-08-10     1.131410     0.663235     0.708087     1.067860  1.463100e+06
# ...                 ...          ...          ...          ...           ...
# 2021-06-14  2639.229248  2515.153076  2587.762695  2610.936768  2.900528e+10
# 2021-06-15  2554.628906  2354.350586  2544.864746  2367.663574  2.410193e+10
# 2021-06-16  2457.175537  2312.301514  2367.306396  2372.001953  2.187163e+10
# 2021-06-17  2377.195068  2147.308350  2374.586914  2231.733154  2.275282e+10
# 2021-06-19  2255.955322  2178.375488  2232.007080  2254.433350  2.396869e+10
#
#               Adj Close
# Date
# 2015-08-06     2.772120
# 2015-08-07     0.753325
# 2015-08-08     0.701897
# 2015-08-09     0.708448
# 2015-08-10     1.067860
# ...                 ...
# 2021-06-14  2610.936768
# 2021-06-15  2367.663574
# 2021-06-16  2372.001953
# 2021-06-17  2231.733154
# 2021-06-19  2254.433350
#
# [2140 rows x 6 columns]

# %%
base_df['Spread'] = base_df.High - base_df.Low
base_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2140 entries, 2015-08-06 to 2021-06-19
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       2140 non-null   float64
#  1   Low        2140 non-null   float64
#  2   Open       2140 non-null   float64
#  3   Close      2140 non-null   float64
#  4   Volume     2140 non-null   float64
#  5   Adj Close  2140 non-null   float64
#  6   Spread     2140 non-null   float64
# dtypes: float64(7)
# memory usage: 133.8 KB

# %% [markdown]
# ## Plot the closing value of Dogecoin over time

# %%
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(y = base_df.Close.values, x=base_df.index.values, alpha=0.8, color=color[3])
ax.xaxis.set_major_locator(mdates.AutoDateLocator())
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y.%m.%d'))
fig.autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price in USD', fontsize=12)
plt.title("Closing price distribution of Ethereum", fontsize=15)
plt.show()

# %% [markdown]
# ## Candlestick chart

# %%
import matplotlib.ticker as mticker
import mplfinance as mpf

#base_df['Date_mpl'] = base_df['Date'].apply(lambda x: mdates.date2num(x))

temp_base_df = base_df.copy(deep=False)
#temp_base_df = temp_base_df.set_index(['Date'])
temp_base_df = temp_base_df.drop(['Spread'], axis=1)
temp_base_df
# Out:
#                    High          Low         Open        Close        Volume  \
# Date
# 2015-08-06     3.536610     2.521120     2.831620     2.772120  1.643290e+05
# 2015-08-07     2.798810     0.714725     2.793760     0.753325  6.741880e+05
# 2015-08-08     0.879810     0.629191     0.706136     0.701897  5.321700e+05
# 2015-08-09     0.729854     0.636546     0.713989     0.708448  4.052830e+05
# 2015-08-10     1.131410     0.663235     0.708087     1.067860  1.463100e+06
# ...                 ...          ...          ...          ...           ...
# 2021-06-14  2639.229248  2515.153076  2587.762695  2610.936768  2.900528e+10
# 2021-06-15  2554.628906  2354.350586  2544.864746  2367.663574  2.410193e+10
# 2021-06-16  2457.175537  2312.301514  2367.306396  2372.001953  2.187163e+10
# 2021-06-17  2377.195068  2147.308350  2374.586914  2231.733154  2.275282e+10
# 2021-06-19  2255.955322  2178.375488  2232.007080  2254.433350  2.396869e+10
#
#               Adj Close
# Date
# 2015-08-06     2.772120
# 2015-08-07     0.753325
# 2015-08-08     0.701897
# 2015-08-09     0.708448
# 2015-08-10     1.067860
# ...                 ...
# 2021-06-14  2610.936768
# 2021-06-15  2367.663574
# 2021-06-16  2372.001953
# 2021-06-17  2231.733154
# 2021-06-19  2254.433350
#
# [2140 rows x 6 columns]

# %%
mpf.plot(temp_base_df.loc['2021-1-1':], type='candle', mav=(5,10), volume=True)

# %% [markdown]
# ## Future Price Prediction

# %%
from fbprophet import Prophet

# %%
base_df
# Out:
#                    High          Low         Open        Close        Volume  \
# Date
# 2015-08-06     3.536610     2.521120     2.831620     2.772120  1.643290e+05
# 2015-08-07     2.798810     0.714725     2.793760     0.753325  6.741880e+05
# 2015-08-08     0.879810     0.629191     0.706136     0.701897  5.321700e+05
# 2015-08-09     0.729854     0.636546     0.713989     0.708448  4.052830e+05
# 2015-08-10     1.131410     0.663235     0.708087     1.067860  1.463100e+06
# ...                 ...          ...          ...          ...           ...
# 2021-06-14  2639.229248  2515.153076  2587.762695  2610.936768  2.900528e+10
# 2021-06-15  2554.628906  2354.350586  2544.864746  2367.663574  2.410193e+10
# 2021-06-16  2457.175537  2312.301514  2367.306396  2372.001953  2.187163e+10
# 2021-06-17  2377.195068  2147.308350  2374.586914  2231.733154  2.275282e+10
# 2021-06-19  2255.955322  2178.375488  2232.007080  2254.433350  2.396869e+10
#
#               Adj Close      Spread
# Date
# 2015-08-06     2.772120    1.015490
# 2015-08-07     0.753325    2.084085
# 2015-08-08     0.701897    0.250619
# 2015-08-09     0.708448    0.093308
# 2015-08-10     1.067860    0.468175
# ...                 ...         ...
# 2021-06-14  2610.936768  124.076172
# 2021-06-15  2367.663574  200.278320
# 2021-06-16  2372.001953  144.874023
# 2021-06-17  2231.733154  229.886719
# 2021-06-19  2254.433350   77.579834
#
# [2140 rows x 7 columns]

# %%
price_predict_df = base_df['Close'].copy(deep=False).reset_index()
price_predict_df.columns = ["ds", "y"]
price_predict_df = price_predict_df[price_predict_df['ds']>'2020-6-1']
price_predict_df
# Out:
#              ds            y
# 1761 2020-06-02   244.179321
# 1762 2020-06-03   244.426392
# 1763 2020-06-04   241.221985
# 1764 2020-06-05   241.931320
# 1765 2020-06-06   245.167252
# ...         ...          ...
# 2135 2021-06-14  2610.936768
# 2136 2021-06-15  2367.663574
# 2137 2021-06-16  2372.001953
# 2138 2021-06-17  2231.733154
# 2139 2021-06-19  2254.433350
#
# [379 rows x 2 columns]

# %%
m = Prophet(changepoint_prior_scale=.7)
m.add_country_holidays(country_name='US')
m.fit(price_predict_df);
m.train_holiday_names

future = m.make_future_dataframe(periods=7)

forecast = m.predict(future)
fig = m.plot_components(forecast)

forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds         yhat   yhat_lower   yhat_upper
# 380 2021-06-22  2967.208637  2627.230711  3297.595334
# 381 2021-06-23  2981.553489  2648.292427  3333.919670
# 382 2021-06-24  2963.197429  2617.536212  3302.634815
# 383 2021-06-25  2983.439160  2624.461546  3315.214809
# 384 2021-06-26  2976.620807  2646.069019  3315.111038

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)
